# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 219.4495 - y1_output_loss: 100.5502 - y2_output_loss: 117.1254 - y1_output_root_mean_squared_error: 10.0623 - y2_output_root_mean_squared_error: 10.8720 - val_loss: 72.7307 - val_y1_output_loss: 22.4316 - val_y2_output_loss: 49.2633 - val_y1_output_root_mean_squared_error: 4.7920 - val_y2_output_root_mean_squared_error: 7.0546
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 30.6046 - y1_output_loss: 12.2500 - y2_output_loss: 18.1462 - y1_output_root_mean_squared_error: 3.5115 - y2_output_root_mean_squared_error: 4.2748 - val_loss: 34.6642 - val_y1_output_loss: 14.2594 - val_y2_output_loss: 19.4403 - val_y1_output_root_mean_squared_error: 3.8393 - val_y2_output_root_mean_squared_error: 4.4636
# Epoch 3/500
# 614/614 [==============================] - 0s 155us/sample - loss: 27.0396 - y1_output_loss: 10.2552 - y2_output_loss: 16.9386 - y1_output_root_mean_squared_error: 3.2026 - y2_output_root_mean_squared_error: 4.0967 - val_loss: 58.6074 - val_y1_output_loss: 14.6134 - val_y2_output_loss: 44.5612 - val_y1_output_root_mean_squared_error: 3.8180 - val_y2_output_root_mean_squared_error: 6.6355
# Epoch 4/500
# 614/614 [==============================] - 0s 157us/sample - loss: 24.4251 - y1_output_loss: 9.2415 - y2_output_loss: 15.4367 - y1_output_root_mean_squared_error: 3.0274 - y2_output_root_mean_squared_error: 3.9064 - val_loss: 71.7315 - val_y1_output_loss: 16.7590 - val_y2_output_loss: 55.2503 - val_y1_output_root_mean_squared_error: 4.0907 - val_y2_output_root_mean_squared_error: 7.4160
# Epoch 5/500
# 614/614 [==============================] - 0s 149us/sample - loss: 24.5639 - y1_output_loss: 9.3125 - y2_output_loss: 15.0759 - y1_output_root_mean_squared_error: 3.0579 - y2_output_root_mean_squared_error: 3.9004 - val_loss: 22.3482 - val_y1_output_loss: 10.4490 - val_y2_output_loss: 11.9410 - val_y1_output_root_mean_squared_error: 3.2618 - val_y2_output_root_mean_squared_error: 3.4219
# Epoch 6/500
# 614/614 [==============================] - 0s 153us/sample - loss: 26.5979 - y1_output_loss: 9.5650 - y2_output_loss: 17.4320 - y1_output_root_mean_squared_error: 3.0849 - y2_output_root_mean_squared_error: 4.1330 - val_loss: 77.0241 - val_y1_output_loss: 14.6518 - val_y2_output_loss: 63.0199 - val_y1_output_root_mean_squared_error: 3.8083 - val_y2_output_root_mean_squared_error: 7.9070
# Epoch 7/500
# 614/614 [==============================] - 0s 148us/sample - loss: 22.2537 - y1_output_loss: 8.1663 - y2_output_loss: 13.9753 - y1_output_root_mean_squared_error: 2.8593 - y2_output_root_mean_squared_error: 3.7521 - val_loss: 20.0341 - val_y1_output_loss: 9.9454 - val_y2_output_loss: 10.9308 - val_y1_output_root_mean_squared_error: 3.1323 - val_y2_output_root_mean_squared_error: 3.1973
# Epoch 8/500
# 614/614 [==============================] - 0s 152us/sample - loss: 28.7989 - y1_output_loss: 9.6199 - y2_output_loss: 19.0300 - y1_output_root_mean_squared_error: 3.1110 - y2_output_root_mean_squared_error: 4.3727 - val_loss: 19.1884 - val_y1_output_loss: 9.5013 - val_y2_output_loss: 10.2534 - val_y1_output_root_mean_squared_error: 3.0678 - val_y2_output_root_mean_squared_error: 3.1268
# Epoch 9/500
# 614/614 [==============================] - 0s 168us/sample - loss: 21.6489 - y1_output_loss: 8.1808 - y2_output_loss: 13.3888 - y1_output_root_mean_squared_error: 2.8682 - y2_output_root_mean_squared_error: 3.6637 - val_loss: 36.5235 - val_y1_output_loss: 11.9634 - val_y2_output_loss: 23.9982 - val_y1_output_root_mean_squared_error: 3.4934 - val_y2_output_root_mean_squared_error: 4.9315
# Epoch 10/500
# 614/614 [==============================] - 0s 148us/sample - loss: 23.8640 - y1_output_loss: 8.4576 - y2_output_loss: 15.3246 - y1_output_root_mean_squared_error: 2.9071 - y2_output_root_mean_squared_error: 3.9259 - val_loss: 32.5323 - val_y1_output_loss: 13.4127 - val_y2_output_loss: 18.4078 - val_y1_output_root_mean_squared_error: 3.7147 - val_y2_output_root_mean_squared_error: 4.3282
# Epoch 11/500
# 614/614 [==============================] - 0s 159us/sample - loss: 21.1893 - y1_output_loss: 7.8761 - y2_output_loss: 13.2662 - y1_output_root_mean_squared_error: 2.8011 - y2_output_root_mean_squared_error: 3.6528 - val_loss: 20.6206 - val_y1_output_loss: 9.7364 - val_y2_output_loss: 11.5357 - val_y1_output_root_mean_squared_error: 3.1017 - val_y2_output_root_mean_squared_error: 3.3166
# Epoch 12/500
# 614/614 [==============================] - 0s 155us/sample - loss: 21.9561 - y1_output_loss: 8.0027 - y2_output_loss: 13.7816 - y1_output_root_mean_squared_error: 2.8416 - y2_output_root_mean_squared_error: 3.7258 - val_loss: 18.3604 - val_y1_output_loss: 9.0283 - val_y2_output_loss: 10.0551 - val_y1_output_root_mean_squared_error: 2.9847 - val_y2_output_root_mean_squared_error: 3.0744
# Epoch 13/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.9210 - y1_output_loss: 7.7891 - y2_output_loss: 13.2223 - y1_output_root_mean_squared_error: 2.7988 - y2_output_root_mean_squared_error: 3.6177 - val_loss: 33.8351 - val_y1_output_loss: 10.5734 - val_y2_output_loss: 22.8378 - val_y1_output_root_mean_squared_error: 3.2775 - val_y2_output_root_mean_squared_error: 4.8055
# Epoch 14/500
# 614/614 [==============================] - 0s 158us/sample - loss: 19.9620 - y1_output_loss: 7.3982 - y2_output_loss: 12.4178 - y1_output_root_mean_squared_error: 2.7316 - y2_output_root_mean_squared_error: 3.5356 - val_loss: 17.7655 - val_y1_output_loss: 8.7313 - val_y2_output_loss: 9.7952 - val_y1_output_root_mean_squared_error: 2.9286 - val_y2_output_root_mean_squared_error: 3.0313
# Epoch 15/500
# 614/614 [==============================] - 0s 140us/sample - loss: 19.6525 - y1_output_loss: 7.1142 - y2_output_loss: 12.4571 - y1_output_root_mean_squared_error: 2.6713 - y2_output_root_mean_squared_error: 3.5379 - val_loss: 17.5406 - val_y1_output_loss: 8.6429 - val_y2_output_loss: 8.9865 - val_y1_output_root_mean_squared_error: 2.9581 - val_y2_output_root_mean_squared_error: 2.9648
# Epoch 16/500
# 614/614 [==============================] - 0s 149us/sample - loss: 19.0239 - y1_output_loss: 7.4151 - y2_output_loss: 11.7373 - y1_output_root_mean_squared_error: 2.7194 - y2_output_root_mean_squared_error: 3.4101 - val_loss: 54.4871 - val_y1_output_loss: 14.4587 - val_y2_output_loss: 38.8400 - val_y1_output_root_mean_squared_error: 3.8517 - val_y2_output_root_mean_squared_error: 6.2970
# Epoch 17/500
# 614/614 [==============================] - 0s 154us/sample - loss: 20.2178 - y1_output_loss: 7.0719 - y2_output_loss: 13.6707 - y1_output_root_mean_squared_error: 2.6421 - y2_output_root_mean_squared_error: 3.6383 - val_loss: 186.6319 - val_y1_output_loss: 29.6902 - val_y2_output_loss: 157.8013 - val_y1_output_root_mean_squared_error: 5.4059 - val_y2_output_root_mean_squared_error: 12.5462
# Epoch 18/500
# 614/614 [==============================] - 0s 147us/sample - loss: 19.2728 - y1_output_loss: 7.1774 - y2_output_loss: 11.9941 - y1_output_root_mean_squared_error: 2.6779 - y2_output_root_mean_squared_error: 3.4787 - val_loss: 18.8298 - val_y1_output_loss: 9.2069 - val_y2_output_loss: 10.6316 - val_y1_output_root_mean_squared_error: 2.9896 - val_y2_output_root_mean_squared_error: 3.1452
# Epoch 19/500
# 614/614 [==============================] - 0s 151us/sample - loss: 18.5233 - y1_output_loss: 6.7417 - y2_output_loss: 11.6662 - y1_output_root_mean_squared_error: 2.6045 - y2_output_root_mean_squared_error: 3.4264 - val_loss: 16.3878 - val_y1_output_loss: 8.0042 - val_y2_output_loss: 9.1902 - val_y1_output_root_mean_squared_error: 2.7892 - val_y2_output_root_mean_squared_error: 2.9339
# Epoch 20/500
# 614/614 [==============================] - 0s 151us/sample - loss: 16.8052 - y1_output_loss: 6.0967 - y2_output_loss: 10.9809 - y1_output_root_mean_squared_error: 2.4601 - y2_output_root_mean_squared_error: 3.2792 - val_loss: 48.9959 - val_y1_output_loss: 13.0886 - val_y2_output_loss: 34.8643 - val_y1_output_root_mean_squared_error: 3.6654 - val_y2_output_root_mean_squared_error: 5.9633
# Epoch 21/500
# 614/614 [==============================] - 0s 150us/sample - loss: 20.8162 - y1_output_loss: 7.1776 - y2_output_loss: 13.7577 - y1_output_root_mean_squared_error: 2.6709 - y2_output_root_mean_squared_error: 3.6990 - val_loss: 20.7489 - val_y1_output_loss: 9.7012 - val_y2_output_loss: 12.0053 - val_y1_output_root_mean_squared_error: 3.0756 - val_y2_output_root_mean_squared_error: 3.3600
# Epoch 22/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.3378 - y1_output_loss: 5.7590 - y2_output_loss: 9.6373 - y1_output_root_mean_squared_error: 2.4102 - y2_output_root_mean_squared_error: 3.0869 - val_loss: 36.8328 - val_y1_output_loss: 10.5351 - val_y2_output_loss: 27.0912 - val_y1_output_root_mean_squared_error: 3.2178 - val_y2_output_root_mean_squared_error: 5.1457
# Epoch 23/500
# 614/614 [==============================] - 0s 151us/sample - loss: 13.8171 - y1_output_loss: 5.3399 - y2_output_loss: 8.4216 - y1_output_root_mean_squared_error: 2.3167 - y2_output_root_mean_squared_error: 2.9069 - val_loss: 56.7499 - val_y1_output_loss: 12.4412 - val_y2_output_loss: 44.9824 - val_y1_output_root_mean_squared_error: 3.5020 - val_y2_output_root_mean_squared_error: 6.6698
# Epoch 24/500
# 614/614 [==============================] - 0s 161us/sample - loss: 16.4740 - y1_output_loss: 5.5054 - y2_output_loss: 10.9900 - y1_output_root_mean_squared_error: 2.3525 - y2_output_root_mean_squared_error: 3.3075 - val_loss: 38.6159 - val_y1_output_loss: 11.7492 - val_y2_output_loss: 25.9477 - val_y1_output_root_mean_squared_error: 3.4799 - val_y2_output_root_mean_squared_error: 5.1484
# Epoch 25/500
# 614/614 [==============================] - 0s 145us/sample - loss: 14.0983 - y1_output_loss: 5.1154 - y2_output_loss: 8.9973 - y1_output_root_mean_squared_error: 2.2664 - y2_output_root_mean_squared_error: 2.9936 - val_loss: 43.4158 - val_y1_output_loss: 9.2806 - val_y2_output_loss: 35.1317 - val_y1_output_root_mean_squared_error: 3.0035 - val_y2_output_root_mean_squared_error: 5.8647
# Epoch 26/500
# 614/614 [==============================] - 0s 149us/sample - loss: 15.8058 - y1_output_loss: 5.5809 - y2_output_loss: 10.1894 - y1_output_root_mean_squared_error: 2.3505 - y2_output_root_mean_squared_error: 3.2064 - val_loss: 11.0360 - val_y1_output_loss: 5.4555 - val_y2_output_loss: 5.9443 - val_y1_output_root_mean_squared_error: 2.3197 - val_y2_output_root_mean_squared_error: 2.3780
# Epoch 27/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.8170 - y1_output_loss: 5.0752 - y2_output_loss: 9.6679 - y1_output_root_mean_squared_error: 2.2609 - y2_output_root_mean_squared_error: 3.1153 - val_loss: 12.2556 - val_y1_output_loss: 5.9395 - val_y2_output_loss: 6.8268 - val_y1_output_root_mean_squared_error: 2.4142 - val_y2_output_root_mean_squared_error: 2.5352
# Epoch 28/500
# 614/614 [==============================] - 0s 145us/sample - loss: 14.0679 - y1_output_loss: 4.8349 - y2_output_loss: 9.3221 - y1_output_root_mean_squared_error: 2.1910 - y2_output_root_mean_squared_error: 3.0442 - val_loss: 10.6341 - val_y1_output_loss: 5.0662 - val_y2_output_loss: 5.8818 - val_y1_output_root_mean_squared_error: 2.2463 - val_y2_output_root_mean_squared_error: 2.3639
# Epoch 29/500
# 614/614 [==============================] - 0s 159us/sample - loss: 12.7334 - y1_output_loss: 4.2888 - y2_output_loss: 8.3478 - y1_output_root_mean_squared_error: 2.0789 - y2_output_root_mean_squared_error: 2.9003 - val_loss: 9.5878 - val_y1_output_loss: 4.4272 - val_y2_output_loss: 5.4759 - val_y1_output_root_mean_squared_error: 2.0917 - val_y2_output_root_mean_squared_error: 2.2831
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.8267 - y1_output_loss: 4.5381 - y2_output_loss: 7.2268 - y1_output_root_mean_squared_error: 2.1346 - y2_output_root_mean_squared_error: 2.6963 - val_loss: 14.9867 - val_y1_output_loss: 7.0412 - val_y2_output_loss: 8.4359 - val_y1_output_root_mean_squared_error: 2.6312 - val_y2_output_root_mean_squared_error: 2.8397
# Epoch 31/500
# 614/614 [==============================] - 0s 165us/sample - loss: 11.8518 - y1_output_loss: 4.0490 - y2_output_loss: 7.7770 - y1_output_root_mean_squared_error: 2.0121 - y2_output_root_mean_squared_error: 2.7935 - val_loss: 26.4511 - val_y1_output_loss: 9.3405 - val_y2_output_loss: 16.6498 - val_y1_output_root_mean_squared_error: 3.0932 - val_y2_output_root_mean_squared_error: 4.1089
# Epoch 32/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.0932 - y1_output_loss: 3.8735 - y2_output_loss: 7.2760 - y1_output_root_mean_squared_error: 1.9547 - y2_output_root_mean_squared_error: 2.6967 - val_loss: 9.4442 - val_y1_output_loss: 4.1022 - val_y2_output_loss: 5.4926 - val_y1_output_root_mean_squared_error: 2.0272 - val_y2_output_root_mean_squared_error: 2.3097
# Epoch 33/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.7883 - y1_output_loss: 3.5108 - y2_output_loss: 6.2282 - y1_output_root_mean_squared_error: 1.8773 - y2_output_root_mean_squared_error: 2.5028 - val_loss: 9.4288 - val_y1_output_loss: 3.9084 - val_y2_output_loss: 5.7417 - val_y1_output_root_mean_squared_error: 1.9743 - val_y2_output_root_mean_squared_error: 2.3518
# Epoch 34/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.8521 - y1_output_loss: 3.6473 - y2_output_loss: 7.2705 - y1_output_root_mean_squared_error: 1.9076 - y2_output_root_mean_squared_error: 2.6857 - val_loss: 8.7135 - val_y1_output_loss: 3.7396 - val_y2_output_loss: 5.1651 - val_y1_output_root_mean_squared_error: 1.9304 - val_y2_output_root_mean_squared_error: 2.2331
# Epoch 35/500
# 614/614 [==============================] - 0s 156us/sample - loss: 11.6736 - y1_output_loss: 3.7294 - y2_output_loss: 7.8408 - y1_output_root_mean_squared_error: 1.9402 - y2_output_root_mean_squared_error: 2.8123 - val_loss: 14.3844 - val_y1_output_loss: 5.9428 - val_y2_output_loss: 8.2079 - val_y1_output_root_mean_squared_error: 2.4675 - val_y2_output_root_mean_squared_error: 2.8802
# Epoch 36/500
# 614/614 [==============================] - 0s 151us/sample - loss: 9.7474 - y1_output_loss: 3.2679 - y2_output_loss: 6.4618 - y1_output_root_mean_squared_error: 1.8007 - y2_output_root_mean_squared_error: 2.5505 - val_loss: 7.8366 - val_y1_output_loss: 3.3862 - val_y2_output_loss: 4.7415 - val_y1_output_root_mean_squared_error: 1.8268 - val_y2_output_root_mean_squared_error: 2.1212
# Epoch 37/500
# 614/614 [==============================] - 0s 155us/sample - loss: 9.0541 - y1_output_loss: 3.0161 - y2_output_loss: 6.0234 - y1_output_root_mean_squared_error: 1.7363 - y2_output_root_mean_squared_error: 2.4575 - val_loss: 12.5060 - val_y1_output_loss: 4.7503 - val_y2_output_loss: 7.4139 - val_y1_output_root_mean_squared_error: 2.2186 - val_y2_output_root_mean_squared_error: 2.7539
# Epoch 38/500
# 614/614 [==============================] - 0s 158us/sample - loss: 13.6233 - y1_output_loss: 4.5468 - y2_output_loss: 8.9879 - y1_output_root_mean_squared_error: 2.1364 - y2_output_root_mean_squared_error: 3.0098 - val_loss: 9.4512 - val_y1_output_loss: 3.7506 - val_y2_output_loss: 5.5593 - val_y1_output_root_mean_squared_error: 1.9611 - val_y2_output_root_mean_squared_error: 2.3676
# Epoch 39/500
# 614/614 [==============================] - 0s 158us/sample - loss: 10.1663 - y1_output_loss: 2.9345 - y2_output_loss: 7.1464 - y1_output_root_mean_squared_error: 1.7187 - y2_output_root_mean_squared_error: 2.6856 - val_loss: 10.7934 - val_y1_output_loss: 3.9964 - val_y2_output_loss: 7.2649 - val_y1_output_root_mean_squared_error: 1.9712 - val_y2_output_root_mean_squared_error: 2.6282
# Epoch 40/500
# 614/614 [==============================] - 0s 165us/sample - loss: 7.6719 - y1_output_loss: 2.6066 - y2_output_loss: 5.0287 - y1_output_root_mean_squared_error: 1.6219 - y2_output_root_mean_squared_error: 2.2453 - val_loss: 14.3254 - val_y1_output_loss: 5.1773 - val_y2_output_loss: 9.3944 - val_y1_output_root_mean_squared_error: 2.2676 - val_y2_output_root_mean_squared_error: 3.0304
# Epoch 41/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.3297 - y1_output_loss: 3.0277 - y2_output_loss: 6.2474 - y1_output_root_mean_squared_error: 1.7417 - y2_output_root_mean_squared_error: 2.5092 - val_loss: 6.9180 - val_y1_output_loss: 2.5761 - val_y2_output_loss: 4.2791 - val_y1_output_root_mean_squared_error: 1.6200 - val_y2_output_root_mean_squared_error: 2.0721
# Epoch 42/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.2508 - y1_output_loss: 2.6874 - y2_output_loss: 5.5434 - y1_output_root_mean_squared_error: 1.6382 - y2_output_root_mean_squared_error: 2.3595 - val_loss: 13.4747 - val_y1_output_loss: 4.4272 - val_y2_output_loss: 8.6998 - val_y1_output_root_mean_squared_error: 2.1393 - val_y2_output_root_mean_squared_error: 2.9829
# Epoch 43/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.2633 - y1_output_loss: 2.6823 - y2_output_loss: 5.5442 - y1_output_root_mean_squared_error: 1.6428 - y2_output_root_mean_squared_error: 2.3589 - val_loss: 27.3167 - val_y1_output_loss: 4.8366 - val_y2_output_loss: 22.5993 - val_y1_output_root_mean_squared_error: 2.1920 - val_y2_output_root_mean_squared_error: 4.7446
# Epoch 44/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9625 - y1_output_loss: 2.2224 - y2_output_loss: 4.6982 - y1_output_root_mean_squared_error: 1.4943 - y2_output_root_mean_squared_error: 2.1747 - val_loss: 6.9826 - val_y1_output_loss: 2.6233 - val_y2_output_loss: 4.4679 - val_y1_output_root_mean_squared_error: 1.6254 - val_y2_output_root_mean_squared_error: 2.0834
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.6755 - y1_output_loss: 2.5836 - y2_output_loss: 6.0102 - y1_output_root_mean_squared_error: 1.6151 - y2_output_root_mean_squared_error: 2.4631 - val_loss: 6.5745 - val_y1_output_loss: 2.4318 - val_y2_output_loss: 4.1979 - val_y1_output_root_mean_squared_error: 1.5643 - val_y2_output_root_mean_squared_error: 2.0316
# Epoch 46/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.7144 - y1_output_loss: 2.1124 - y2_output_loss: 4.5803 - y1_output_root_mean_squared_error: 1.4581 - y2_output_root_mean_squared_error: 2.1420 - val_loss: 15.2034 - val_y1_output_loss: 3.4754 - val_y2_output_loss: 11.7343 - val_y1_output_root_mean_squared_error: 1.8718 - val_y2_output_root_mean_squared_error: 3.4205
# Epoch 47/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.6115 - y1_output_loss: 2.6506 - y2_output_loss: 5.9210 - y1_output_root_mean_squared_error: 1.6335 - y2_output_root_mean_squared_error: 2.4379 - val_loss: 8.6957 - val_y1_output_loss: 2.5679 - val_y2_output_loss: 6.2055 - val_y1_output_root_mean_squared_error: 1.6053 - val_y2_output_root_mean_squared_error: 2.4736
# Epoch 48/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.3953 - y1_output_loss: 2.1500 - y2_output_loss: 4.2326 - y1_output_root_mean_squared_error: 1.4660 - y2_output_root_mean_squared_error: 2.0606 - val_loss: 9.4521 - val_y1_output_loss: 3.3848 - val_y2_output_loss: 5.7680 - val_y1_output_root_mean_squared_error: 1.8716 - val_y2_output_root_mean_squared_error: 2.4391
# Epoch 49/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.8643 - y1_output_loss: 2.1423 - y2_output_loss: 4.6582 - y1_output_root_mean_squared_error: 1.4703 - y2_output_root_mean_squared_error: 2.1686 - val_loss: 7.5065 - val_y1_output_loss: 2.6406 - val_y2_output_loss: 4.6756 - val_y1_output_root_mean_squared_error: 1.6464 - val_y2_output_root_mean_squared_error: 2.1899
# Epoch 50/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.4487 - y1_output_loss: 2.4216 - y2_output_loss: 5.2863 - y1_output_root_mean_squared_error: 1.5526 - y2_output_root_mean_squared_error: 2.2446 - val_loss: 43.6641 - val_y1_output_loss: 10.1818 - val_y2_output_loss: 32.0532 - val_y1_output_root_mean_squared_error: 3.2483 - val_y2_output_root_mean_squared_error: 5.7543
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.4255 - y1_output_loss: 2.3152 - y2_output_loss: 5.0666 - y1_output_root_mean_squared_error: 1.5213 - y2_output_root_mean_squared_error: 2.2608 - val_loss: 7.1995 - val_y1_output_loss: 2.8422 - val_y2_output_loss: 4.1862 - val_y1_output_root_mean_squared_error: 1.7136 - val_y2_output_root_mean_squared_error: 2.0647
# Epoch 52/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.8620 - y1_output_loss: 2.1927 - y2_output_loss: 4.6145 - y1_output_root_mean_squared_error: 1.4858 - y2_output_root_mean_squared_error: 2.1574 - val_loss: 6.7051 - val_y1_output_loss: 2.5037 - val_y2_output_loss: 4.2714 - val_y1_output_root_mean_squared_error: 1.5853 - val_y2_output_root_mean_squared_error: 2.0474
# Epoch 53/500
# 614/614 [==============================] - 0s 155us/sample - loss: 6.1088 - y1_output_loss: 1.9531 - y2_output_loss: 4.2083 - y1_output_root_mean_squared_error: 1.4027 - y2_output_root_mean_squared_error: 2.0350 - val_loss: 15.1382 - val_y1_output_loss: 2.2168 - val_y2_output_loss: 12.9417 - val_y1_output_root_mean_squared_error: 1.4927 - val_y2_output_root_mean_squared_error: 3.5931
# Epoch 54/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.7248 - y1_output_loss: 1.8107 - y2_output_loss: 3.9065 - y1_output_root_mean_squared_error: 1.3415 - y2_output_root_mean_squared_error: 1.9812 - val_loss: 7.6199 - val_y1_output_loss: 2.4604 - val_y2_output_loss: 5.0282 - val_y1_output_root_mean_squared_error: 1.5844 - val_y2_output_root_mean_squared_error: 2.2604
# Epoch 55/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.0344 - y1_output_loss: 1.9768 - y2_output_loss: 5.0385 - y1_output_root_mean_squared_error: 1.4082 - y2_output_root_mean_squared_error: 2.2475 - val_loss: 5.7646 - val_y1_output_loss: 2.0283 - val_y2_output_loss: 3.7122 - val_y1_output_root_mean_squared_error: 1.4387 - val_y2_output_root_mean_squared_error: 1.9222
# Epoch 56/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.5194 - y1_output_loss: 2.1355 - y2_output_loss: 4.3396 - y1_output_root_mean_squared_error: 1.4642 - y2_output_root_mean_squared_error: 2.0918 - val_loss: 6.2889 - val_y1_output_loss: 1.7875 - val_y2_output_loss: 4.3876 - val_y1_output_root_mean_squared_error: 1.3455 - val_y2_output_root_mean_squared_error: 2.1163
# Epoch 57/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.4080 - y1_output_loss: 2.1462 - y2_output_loss: 5.2418 - y1_output_root_mean_squared_error: 1.4678 - y2_output_root_mean_squared_error: 2.2921 - val_loss: 7.4121 - val_y1_output_loss: 1.9899 - val_y2_output_loss: 5.2252 - val_y1_output_root_mean_squared_error: 1.4337 - val_y2_output_root_mean_squared_error: 2.3144
# Epoch 58/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.1316 - y1_output_loss: 2.7957 - y2_output_loss: 7.2433 - y1_output_root_mean_squared_error: 1.6800 - y2_output_root_mean_squared_error: 2.7036 - val_loss: 8.4687 - val_y1_output_loss: 2.5295 - val_y2_output_loss: 5.6967 - val_y1_output_root_mean_squared_error: 1.6196 - val_y2_output_root_mean_squared_error: 2.4178
# Epoch 59/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.3939 - y1_output_loss: 1.6008 - y2_output_loss: 3.7458 - y1_output_root_mean_squared_error: 1.2711 - y2_output_root_mean_squared_error: 1.9438 - val_loss: 7.4046 - val_y1_output_loss: 2.0725 - val_y2_output_loss: 5.2693 - val_y1_output_root_mean_squared_error: 1.4534 - val_y2_output_root_mean_squared_error: 2.3005
# Epoch 60/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7240 - y1_output_loss: 1.9903 - y2_output_loss: 4.7493 - y1_output_root_mean_squared_error: 1.4022 - y2_output_root_mean_squared_error: 2.1813 - val_loss: 19.8130 - val_y1_output_loss: 6.1656 - val_y2_output_loss: 13.5392 - val_y1_output_root_mean_squared_error: 2.4935 - val_y2_output_root_mean_squared_error: 3.6872
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.0335 - y1_output_loss: 1.6736 - y2_output_loss: 4.3623 - y1_output_root_mean_squared_error: 1.2889 - y2_output_root_mean_squared_error: 2.0910 - val_loss: 5.9225 - val_y1_output_loss: 1.7759 - val_y2_output_loss: 4.0624 - val_y1_output_root_mean_squared_error: 1.3471 - val_y2_output_root_mean_squared_error: 2.0268
# Epoch 62/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.1796 - y1_output_loss: 1.6077 - y2_output_loss: 3.5911 - y1_output_root_mean_squared_error: 1.2604 - y2_output_root_mean_squared_error: 1.8950 - val_loss: 17.5892 - val_y1_output_loss: 5.1586 - val_y2_output_loss: 12.4147 - val_y1_output_root_mean_squared_error: 2.2740 - val_y2_output_root_mean_squared_error: 3.5239
# Epoch 63/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.8717 - y1_output_loss: 1.8451 - y2_output_loss: 4.9966 - y1_output_root_mean_squared_error: 1.3630 - y2_output_root_mean_squared_error: 2.2392 - val_loss: 8.5045 - val_y1_output_loss: 1.8815 - val_y2_output_loss: 6.5940 - val_y1_output_root_mean_squared_error: 1.3839 - val_y2_output_root_mean_squared_error: 2.5670
# Epoch 64/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.5496 - y1_output_loss: 1.8726 - y2_output_loss: 4.6585 - y1_output_root_mean_squared_error: 1.3612 - y2_output_root_mean_squared_error: 2.1672 - val_loss: 6.3009 - val_y1_output_loss: 1.6871 - val_y2_output_loss: 4.6228 - val_y1_output_root_mean_squared_error: 1.3026 - val_y2_output_root_mean_squared_error: 2.1457
# Epoch 65/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8043 - y1_output_loss: 1.6386 - y2_output_loss: 4.1365 - y1_output_root_mean_squared_error: 1.2834 - y2_output_root_mean_squared_error: 2.0389 - val_loss: 7.7453 - val_y1_output_loss: 1.7376 - val_y2_output_loss: 5.7941 - val_y1_output_root_mean_squared_error: 1.3374 - val_y2_output_root_mean_squared_error: 2.4406
# Epoch 66/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.7164 - y1_output_loss: 1.5707 - y2_output_loss: 4.3617 - y1_output_root_mean_squared_error: 1.2428 - y2_output_root_mean_squared_error: 2.0425 - val_loss: 60.3299 - val_y1_output_loss: 15.1796 - val_y2_output_loss: 43.9452 - val_y1_output_root_mean_squared_error: 3.9462 - val_y2_output_root_mean_squared_error: 6.6901
# Epoch 67/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.4291 - y1_output_loss: 1.6687 - y2_output_loss: 4.7689 - y1_output_root_mean_squared_error: 1.2916 - y2_output_root_mean_squared_error: 2.1819 - val_loss: 16.5747 - val_y1_output_loss: 4.9914 - val_y2_output_loss: 11.6210 - val_y1_output_root_mean_squared_error: 2.2375 - val_y2_output_root_mean_squared_error: 3.4012
# Epoch 68/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.2772 - y1_output_loss: 1.8711 - y2_output_loss: 4.3565 - y1_output_root_mean_squared_error: 1.3722 - y2_output_root_mean_squared_error: 2.0963 - val_loss: 5.3832 - val_y1_output_loss: 1.6669 - val_y2_output_loss: 3.6216 - val_y1_output_root_mean_squared_error: 1.3030 - val_y2_output_root_mean_squared_error: 1.9197
# Epoch 69/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.4078 - y1_output_loss: 1.3099 - y2_output_loss: 3.1106 - y1_output_root_mean_squared_error: 1.1397 - y2_output_root_mean_squared_error: 1.7632 - val_loss: 5.9510 - val_y1_output_loss: 1.5537 - val_y2_output_loss: 4.4053 - val_y1_output_root_mean_squared_error: 1.2520 - val_y2_output_root_mean_squared_error: 2.0937
# Epoch 70/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.6353 - y1_output_loss: 1.3164 - y2_output_loss: 3.3261 - y1_output_root_mean_squared_error: 1.1445 - y2_output_root_mean_squared_error: 1.8235 - val_loss: 10.5402 - val_y1_output_loss: 2.8192 - val_y2_output_loss: 7.3927 - val_y1_output_root_mean_squared_error: 1.7032 - val_y2_output_root_mean_squared_error: 2.7639
# Epoch 71/500
# 614/614 [==============================] - 0s 154us/sample - loss: 8.1021 - y1_output_loss: 2.4921 - y2_output_loss: 5.5967 - y1_output_root_mean_squared_error: 1.5798 - y2_output_root_mean_squared_error: 2.3677 - val_loss: 4.6778 - val_y1_output_loss: 1.3868 - val_y2_output_loss: 3.2011 - val_y1_output_root_mean_squared_error: 1.1950 - val_y2_output_root_mean_squared_error: 1.8027
# Epoch 72/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.7169 - y1_output_loss: 1.9900 - y2_output_loss: 4.7225 - y1_output_root_mean_squared_error: 1.4170 - y2_output_root_mean_squared_error: 2.1701 - val_loss: 18.2068 - val_y1_output_loss: 3.0012 - val_y2_output_loss: 15.2445 - val_y1_output_root_mean_squared_error: 1.7319 - val_y2_output_root_mean_squared_error: 3.8997
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.5931 - y1_output_loss: 1.7973 - y2_output_loss: 4.7692 - y1_output_root_mean_squared_error: 1.3465 - y2_output_root_mean_squared_error: 2.1863 - val_loss: 5.9615 - val_y1_output_loss: 1.4873 - val_y2_output_loss: 4.3261 - val_y1_output_root_mean_squared_error: 1.2345 - val_y2_output_root_mean_squared_error: 2.1065
# Epoch 74/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.1382 - y1_output_loss: 1.3046 - y2_output_loss: 3.8323 - y1_output_root_mean_squared_error: 1.1301 - y2_output_root_mean_squared_error: 1.9649 - val_loss: 6.0406 - val_y1_output_loss: 1.6985 - val_y2_output_loss: 4.1832 - val_y1_output_root_mean_squared_error: 1.3270 - val_y2_output_root_mean_squared_error: 2.0687
# Epoch 75/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.8335 - y1_output_loss: 1.2015 - y2_output_loss: 3.5892 - y1_output_root_mean_squared_error: 1.1010 - y2_output_root_mean_squared_error: 1.9030 - val_loss: 5.4519 - val_y1_output_loss: 1.5943 - val_y2_output_loss: 3.7086 - val_y1_output_root_mean_squared_error: 1.2794 - val_y2_output_root_mean_squared_error: 1.9532
# Epoch 76/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.4349 - y1_output_loss: 1.1634 - y2_output_loss: 3.2374 - y1_output_root_mean_squared_error: 1.0812 - y2_output_root_mean_squared_error: 1.8072 - val_loss: 4.4221 - val_y1_output_loss: 1.3563 - val_y2_output_loss: 3.0669 - val_y1_output_root_mean_squared_error: 1.1608 - val_y2_output_root_mean_squared_error: 1.7535
# Epoch 77/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.8739 - y1_output_loss: 1.0068 - y2_output_loss: 2.9224 - y1_output_root_mean_squared_error: 1.0036 - y2_output_root_mean_squared_error: 1.6931 - val_loss: 12.0018 - val_y1_output_loss: 1.6499 - val_y2_output_loss: 10.4138 - val_y1_output_root_mean_squared_error: 1.2803 - val_y2_output_root_mean_squared_error: 3.2191
# Epoch 78/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.2745 - y1_output_loss: 0.9510 - y2_output_loss: 3.3346 - y1_output_root_mean_squared_error: 0.9784 - y2_output_root_mean_squared_error: 1.8213 - val_loss: 4.6280 - val_y1_output_loss: 1.4717 - val_y2_output_loss: 3.0594 - val_y1_output_root_mean_squared_error: 1.2354 - val_y2_output_root_mean_squared_error: 1.7612
# Epoch 79/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.6090 - y1_output_loss: 1.0478 - y2_output_loss: 3.5847 - y1_output_root_mean_squared_error: 1.0261 - y2_output_root_mean_squared_error: 1.8858 - val_loss: 6.4223 - val_y1_output_loss: 1.3691 - val_y2_output_loss: 4.9515 - val_y1_output_root_mean_squared_error: 1.1898 - val_y2_output_root_mean_squared_error: 2.2376
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7660 - y1_output_loss: 0.8661 - y2_output_loss: 2.8824 - y1_output_root_mean_squared_error: 0.9298 - y2_output_root_mean_squared_error: 1.7034 - val_loss: 5.8807 - val_y1_output_loss: 1.7630 - val_y2_output_loss: 3.9206 - val_y1_output_root_mean_squared_error: 1.3489 - val_y2_output_root_mean_squared_error: 2.0152
# Epoch 81/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.4699 - y1_output_loss: 1.0111 - y2_output_loss: 3.4265 - y1_output_root_mean_squared_error: 1.0091 - y2_output_root_mean_squared_error: 1.8579 - val_loss: 3.8135 - val_y1_output_loss: 0.9584 - val_y2_output_loss: 2.7693 - val_y1_output_root_mean_squared_error: 0.9942 - val_y2_output_root_mean_squared_error: 1.6808
# Epoch 82/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9304 - y1_output_loss: 0.8242 - y2_output_loss: 3.1068 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.7625 - val_loss: 6.5548 - val_y1_output_loss: 1.7316 - val_y2_output_loss: 4.6967 - val_y1_output_root_mean_squared_error: 1.3371 - val_y2_output_root_mean_squared_error: 2.1834
# Epoch 83/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9891 - y1_output_loss: 0.8945 - y2_output_loss: 3.0627 - y1_output_root_mean_squared_error: 0.9490 - y2_output_root_mean_squared_error: 1.7574 - val_loss: 4.3878 - val_y1_output_loss: 0.9491 - val_y2_output_loss: 3.3425 - val_y1_output_root_mean_squared_error: 0.9898 - val_y2_output_root_mean_squared_error: 1.8461
# Epoch 84/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.0379 - y1_output_loss: 0.9653 - y2_output_loss: 3.1126 - y1_output_root_mean_squared_error: 0.9818 - y2_output_root_mean_squared_error: 1.7533 - val_loss: 10.9990 - val_y1_output_loss: 2.0155 - val_y2_output_loss: 8.8603 - val_y1_output_root_mean_squared_error: 1.4366 - val_y2_output_root_mean_squared_error: 2.9892
# Epoch 85/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.3549 - y1_output_loss: 1.5146 - y2_output_loss: 3.8175 - y1_output_root_mean_squared_error: 1.2352 - y2_output_root_mean_squared_error: 1.9568 - val_loss: 15.6781 - val_y1_output_loss: 2.7727 - val_y2_output_loss: 12.7411 - val_y1_output_root_mean_squared_error: 1.6826 - val_y2_output_root_mean_squared_error: 3.5843
# Epoch 86/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.8880 - y1_output_loss: 0.9438 - y2_output_loss: 2.9381 - y1_output_root_mean_squared_error: 0.9703 - y2_output_root_mean_squared_error: 1.7165 - val_loss: 8.8086 - val_y1_output_loss: 2.9497 - val_y2_output_loss: 5.5729 - val_y1_output_root_mean_squared_error: 1.7495 - val_y2_output_root_mean_squared_error: 2.3974
# Epoch 87/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.7892 - y1_output_loss: 0.8355 - y2_output_loss: 3.0467 - y1_output_root_mean_squared_error: 0.9087 - y2_output_root_mean_squared_error: 1.7215 - val_loss: 18.3711 - val_y1_output_loss: 5.0007 - val_y2_output_loss: 12.9856 - val_y1_output_root_mean_squared_error: 2.2684 - val_y2_output_root_mean_squared_error: 3.6367
# Epoch 88/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.7860 - y1_output_loss: 1.0901 - y2_output_loss: 3.7260 - y1_output_root_mean_squared_error: 1.0485 - y2_output_root_mean_squared_error: 1.9201 - val_loss: 13.8452 - val_y1_output_loss: 2.3161 - val_y2_output_loss: 11.4655 - val_y1_output_root_mean_squared_error: 1.5314 - val_y2_output_root_mean_squared_error: 3.3912
# Epoch 89/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.3204 - y1_output_loss: 0.7130 - y2_output_loss: 2.5862 - y1_output_root_mean_squared_error: 0.8465 - y2_output_root_mean_squared_error: 1.6136 - val_loss: 4.1695 - val_y1_output_loss: 0.9450 - val_y2_output_loss: 3.0995 - val_y1_output_root_mean_squared_error: 0.9838 - val_y2_output_root_mean_squared_error: 1.7893
# Epoch 90/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.9314 - y1_output_loss: 0.6635 - y2_output_loss: 2.2412 - y1_output_root_mean_squared_error: 0.8179 - y2_output_root_mean_squared_error: 1.5042 - val_loss: 3.5739 - val_y1_output_loss: 0.7367 - val_y2_output_loss: 2.7943 - val_y1_output_root_mean_squared_error: 0.8653 - val_y2_output_root_mean_squared_error: 1.6808
# Epoch 91/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.2758 - y1_output_loss: 0.7330 - y2_output_loss: 2.5146 - y1_output_root_mean_squared_error: 0.8587 - y2_output_root_mean_squared_error: 1.5933 - val_loss: 4.5811 - val_y1_output_loss: 0.7229 - val_y2_output_loss: 3.8003 - val_y1_output_root_mean_squared_error: 0.8636 - val_y2_output_root_mean_squared_error: 1.9584
# Epoch 92/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.7652 - y1_output_loss: 0.9072 - y2_output_loss: 2.8311 - y1_output_root_mean_squared_error: 0.9535 - y2_output_root_mean_squared_error: 1.6900 - val_loss: 3.8863 - val_y1_output_loss: 1.0611 - val_y2_output_loss: 2.7083 - val_y1_output_root_mean_squared_error: 1.0490 - val_y2_output_root_mean_squared_error: 1.6691
# Epoch 93/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.2021 - y1_output_loss: 0.6610 - y2_output_loss: 2.5671 - y1_output_root_mean_squared_error: 0.8100 - y2_output_root_mean_squared_error: 1.5956 - val_loss: 5.8227 - val_y1_output_loss: 2.3221 - val_y2_output_loss: 3.3298 - val_y1_output_root_mean_squared_error: 1.5473 - val_y2_output_root_mean_squared_error: 1.8517
# Epoch 94/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.2965 - y1_output_loss: 0.7826 - y2_output_loss: 2.4878 - y1_output_root_mean_squared_error: 0.8886 - y2_output_root_mean_squared_error: 1.5833 - val_loss: 3.2583 - val_y1_output_loss: 0.6789 - val_y2_output_loss: 2.5466 - val_y1_output_root_mean_squared_error: 0.8349 - val_y2_output_root_mean_squared_error: 1.6004
# Epoch 95/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.5723 - y1_output_loss: 0.8945 - y2_output_loss: 2.6985 - y1_output_root_mean_squared_error: 0.9454 - y2_output_root_mean_squared_error: 1.6366 - val_loss: 3.9584 - val_y1_output_loss: 0.7090 - val_y2_output_loss: 3.1862 - val_y1_output_root_mean_squared_error: 0.8524 - val_y2_output_root_mean_squared_error: 1.7977
# Epoch 96/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.9134 - y1_output_loss: 0.6451 - y2_output_loss: 2.2491 - y1_output_root_mean_squared_error: 0.8028 - y2_output_root_mean_squared_error: 1.5063 - val_loss: 3.6980 - val_y1_output_loss: 0.8016 - val_y2_output_loss: 2.8209 - val_y1_output_root_mean_squared_error: 0.9079 - val_y2_output_root_mean_squared_error: 1.6952
# Epoch 97/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.3596 - y1_output_loss: 0.4927 - y2_output_loss: 1.8849 - y1_output_root_mean_squared_error: 0.7023 - y2_output_root_mean_squared_error: 1.3661 - val_loss: 5.0620 - val_y1_output_loss: 0.6428 - val_y2_output_loss: 4.2741 - val_y1_output_root_mean_squared_error: 0.8162 - val_y2_output_root_mean_squared_error: 2.0966
# Epoch 98/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0235 - y1_output_loss: 0.6622 - y2_output_loss: 2.3729 - y1_output_root_mean_squared_error: 0.8085 - y2_output_root_mean_squared_error: 1.5394 - val_loss: 5.2670 - val_y1_output_loss: 0.6918 - val_y2_output_loss: 4.4212 - val_y1_output_root_mean_squared_error: 0.8431 - val_y2_output_root_mean_squared_error: 2.1345
# Epoch 99/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.7008 - y1_output_loss: 0.7214 - y2_output_loss: 2.9570 - y1_output_root_mean_squared_error: 0.8505 - y2_output_root_mean_squared_error: 1.7255 - val_loss: 4.6720 - val_y1_output_loss: 1.2072 - val_y2_output_loss: 3.3940 - val_y1_output_root_mean_squared_error: 1.1114 - val_y2_output_root_mean_squared_error: 1.8538
# Epoch 100/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.7442 - y1_output_loss: 0.5954 - y2_output_loss: 2.1381 - y1_output_root_mean_squared_error: 0.7705 - y2_output_root_mean_squared_error: 1.4665 - val_loss: 4.4799 - val_y1_output_loss: 1.4114 - val_y2_output_loss: 2.9232 - val_y1_output_root_mean_squared_error: 1.2099 - val_y2_output_root_mean_squared_error: 1.7367
# Epoch 101/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.9907 - y1_output_loss: 0.6473 - y2_output_loss: 2.3628 - y1_output_root_mean_squared_error: 0.8034 - y2_output_root_mean_squared_error: 1.5314 - val_loss: 3.6163 - val_y1_output_loss: 0.7338 - val_y2_output_loss: 2.7838 - val_y1_output_root_mean_squared_error: 0.8655 - val_y2_output_root_mean_squared_error: 1.6933
# Epoch 102/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.3891 - y1_output_loss: 0.6650 - y2_output_loss: 2.6933 - y1_output_root_mean_squared_error: 0.8192 - y2_output_root_mean_squared_error: 1.6486 - val_loss: 3.6693 - val_y1_output_loss: 0.7610 - val_y2_output_loss: 2.8270 - val_y1_output_root_mean_squared_error: 0.8842 - val_y2_output_root_mean_squared_error: 1.6993
# Epoch 103/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.4109 - y1_output_loss: 1.1204 - y2_output_loss: 3.2709 - y1_output_root_mean_squared_error: 1.0572 - y2_output_root_mean_squared_error: 1.8147 - val_loss: 3.8407 - val_y1_output_loss: 0.9252 - val_y2_output_loss: 2.8185 - val_y1_output_root_mean_squared_error: 0.9725 - val_y2_output_root_mean_squared_error: 1.7014
# Epoch 104/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.9747 - y1_output_loss: 0.6403 - y2_output_loss: 2.3495 - y1_output_root_mean_squared_error: 0.7901 - y2_output_root_mean_squared_error: 1.5331 - val_loss: 3.3059 - val_y1_output_loss: 0.8430 - val_y2_output_loss: 2.3955 - val_y1_output_root_mean_squared_error: 0.9330 - val_y2_output_root_mean_squared_error: 1.5606
# Epoch 105/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.2463 - y1_output_loss: 0.7225 - y2_output_loss: 2.5213 - y1_output_root_mean_squared_error: 0.8464 - y2_output_root_mean_squared_error: 1.5906 - val_loss: 4.2334 - val_y1_output_loss: 0.6263 - val_y2_output_loss: 3.4806 - val_y1_output_root_mean_squared_error: 0.7989 - val_y2_output_root_mean_squared_error: 1.8961
# Epoch 106/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8173 - y1_output_loss: 0.7213 - y2_output_loss: 2.1048 - y1_output_root_mean_squared_error: 0.8488 - y2_output_root_mean_squared_error: 1.4480 - val_loss: 5.5762 - val_y1_output_loss: 0.7124 - val_y2_output_loss: 4.7707 - val_y1_output_root_mean_squared_error: 0.8581 - val_y2_output_root_mean_squared_error: 2.2000
# Epoch 107/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.2938 - y1_output_loss: 1.5722 - y2_output_loss: 3.6937 - y1_output_root_mean_squared_error: 1.2592 - y2_output_root_mean_squared_error: 1.9257 - val_loss: 11.1549 - val_y1_output_loss: 3.8047 - val_y2_output_loss: 6.9866 - val_y1_output_root_mean_squared_error: 1.9854 - val_y2_output_root_mean_squared_error: 2.6857
# Epoch 108/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.0028 - y1_output_loss: 0.6680 - y2_output_loss: 2.3137 - y1_output_root_mean_squared_error: 0.8192 - y2_output_root_mean_squared_error: 1.5270 - val_loss: 2.9603 - val_y1_output_loss: 0.5888 - val_y2_output_loss: 2.3210 - val_y1_output_root_mean_squared_error: 0.7759 - val_y2_output_root_mean_squared_error: 1.5357
# Epoch 109/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.0440 - y1_output_loss: 0.9565 - y2_output_loss: 3.0523 - y1_output_root_mean_squared_error: 0.9815 - y2_output_root_mean_squared_error: 1.7552 - val_loss: 3.6506 - val_y1_output_loss: 0.7148 - val_y2_output_loss: 2.8837 - val_y1_output_root_mean_squared_error: 0.8568 - val_y2_output_root_mean_squared_error: 1.7078
# Epoch 110/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.1194 - y1_output_loss: 0.5606 - y2_output_loss: 2.5365 - y1_output_root_mean_squared_error: 0.7503 - y2_output_root_mean_squared_error: 1.5989 - val_loss: 3.0491 - val_y1_output_loss: 0.6098 - val_y2_output_loss: 2.3430 - val_y1_output_root_mean_squared_error: 0.7923 - val_y2_output_root_mean_squared_error: 1.5561
# Epoch 111/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.3273 - y1_output_loss: 0.5088 - y2_output_loss: 1.8475 - y1_output_root_mean_squared_error: 0.7164 - y2_output_root_mean_squared_error: 1.3468 - val_loss: 12.3726 - val_y1_output_loss: 0.9810 - val_y2_output_loss: 11.2056 - val_y1_output_root_mean_squared_error: 1.0041 - val_y2_output_root_mean_squared_error: 3.3711
# Epoch 112/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.4635 - y1_output_loss: 0.7348 - y2_output_loss: 2.6977 - y1_output_root_mean_squared_error: 0.8613 - y2_output_root_mean_squared_error: 1.6497 - val_loss: 2.8209 - val_y1_output_loss: 0.6224 - val_y2_output_loss: 2.1279 - val_y1_output_root_mean_squared_error: 0.8002 - val_y2_output_root_mean_squared_error: 1.4767
# Epoch 113/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.6196 - y1_output_loss: 1.0705 - y2_output_loss: 3.5537 - y1_output_root_mean_squared_error: 1.0322 - y2_output_root_mean_squared_error: 1.8852 - val_loss: 6.7635 - val_y1_output_loss: 1.6566 - val_y2_output_loss: 4.9392 - val_y1_output_root_mean_squared_error: 1.3081 - val_y2_output_root_mean_squared_error: 2.2477
# Epoch 114/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.4596 - y1_output_loss: 0.5825 - y2_output_loss: 1.8693 - y1_output_root_mean_squared_error: 0.7649 - y2_output_root_mean_squared_error: 1.3692 - val_loss: 2.9999 - val_y1_output_loss: 0.7023 - val_y2_output_loss: 2.2460 - val_y1_output_root_mean_squared_error: 0.8367 - val_y2_output_root_mean_squared_error: 1.5165
# Epoch 115/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.5958 - y1_output_loss: 0.5409 - y2_output_loss: 2.0366 - y1_output_root_mean_squared_error: 0.7381 - y2_output_root_mean_squared_error: 1.4321 - val_loss: 3.1609 - val_y1_output_loss: 0.5802 - val_y2_output_loss: 2.5158 - val_y1_output_root_mean_squared_error: 0.7730 - val_y2_output_root_mean_squared_error: 1.6011
# Epoch 116/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.3788 - y1_output_loss: 0.4993 - y2_output_loss: 1.8758 - y1_output_root_mean_squared_error: 0.7033 - y2_output_root_mean_squared_error: 1.3726 - val_loss: 2.7828 - val_y1_output_loss: 0.4932 - val_y2_output_loss: 2.2089 - val_y1_output_root_mean_squared_error: 0.7141 - val_y2_output_root_mean_squared_error: 1.5076
# Epoch 117/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.3702 - y1_output_loss: 0.4675 - y2_output_loss: 1.8982 - y1_output_root_mean_squared_error: 0.6855 - y2_output_root_mean_squared_error: 1.3785 - val_loss: 3.4871 - val_y1_output_loss: 0.8576 - val_y2_output_loss: 2.5774 - val_y1_output_root_mean_squared_error: 0.9378 - val_y2_output_root_mean_squared_error: 1.6148
# Epoch 118/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.6201 - y1_output_loss: 0.5000 - y2_output_loss: 2.1102 - y1_output_root_mean_squared_error: 0.7093 - y2_output_root_mean_squared_error: 1.4550 - val_loss: 2.7405 - val_y1_output_loss: 0.6513 - val_y2_output_loss: 2.0144 - val_y1_output_root_mean_squared_error: 0.8218 - val_y2_output_root_mean_squared_error: 1.4370
# Epoch 119/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.2164 - y1_output_loss: 0.6154 - y2_output_loss: 2.5896 - y1_output_root_mean_squared_error: 0.7790 - y2_output_root_mean_squared_error: 1.6154 - val_loss: 4.1034 - val_y1_output_loss: 0.5737 - val_y2_output_loss: 3.4131 - val_y1_output_root_mean_squared_error: 0.7680 - val_y2_output_root_mean_squared_error: 1.8745
# Epoch 120/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.3838 - y1_output_loss: 1.3632 - y2_output_loss: 3.9766 - y1_output_root_mean_squared_error: 1.1708 - y2_output_root_mean_squared_error: 2.0032 - val_loss: 2.9492 - val_y1_output_loss: 0.6401 - val_y2_output_loss: 2.2198 - val_y1_output_root_mean_squared_error: 0.8126 - val_y2_output_root_mean_squared_error: 1.5129
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5127 - y1_output_loss: 0.1576 - y2_output_loss: 0.3522 - y1_output_root_mean_squared_error: 0.3986 - y2_output_root_mean_squared_error: 0.5949 - val_loss: 0.8941 - val_y1_output_loss: 0.1749 - val_y2_output_loss: 0.7041 - val_y1_output_root_mean_squared_error: 0.4234 - val_y2_output_root_mean_squared_error: 0.8455
# Epoch 462/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5211 - y1_output_loss: 0.1496 - y2_output_loss: 0.3718 - y1_output_root_mean_squared_error: 0.3866 - y2_output_root_mean_squared_error: 0.6096 - val_loss: 1.0436 - val_y1_output_loss: 0.2549 - val_y2_output_loss: 0.7733 - val_y1_output_root_mean_squared_error: 0.5113 - val_y2_output_root_mean_squared_error: 0.8844
# Epoch 463/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4694 - y1_output_loss: 0.1344 - y2_output_loss: 0.3386 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.5792 - val_loss: 1.4180 - val_y1_output_loss: 0.2659 - val_y2_output_loss: 1.1207 - val_y1_output_root_mean_squared_error: 0.5208 - val_y2_output_root_mean_squared_error: 1.0709
# Epoch 464/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3955 - y1_output_loss: 0.1226 - y2_output_loss: 0.2704 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5213 - val_loss: 0.9806 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.7217 - val_y1_output_root_mean_squared_error: 0.4996 - val_y2_output_root_mean_squared_error: 0.8550
# Epoch 465/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.5947 - y1_output_loss: 0.1475 - y2_output_loss: 0.4437 - y1_output_root_mean_squared_error: 0.3855 - y2_output_root_mean_squared_error: 0.6679 - val_loss: 0.8296 - val_y1_output_loss: 0.1829 - val_y2_output_loss: 0.6278 - val_y1_output_root_mean_squared_error: 0.4336 - val_y2_output_root_mean_squared_error: 0.8010
# Epoch 466/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5015 - y1_output_loss: 0.1477 - y2_output_loss: 0.3520 - y1_output_root_mean_squared_error: 0.3848 - y2_output_root_mean_squared_error: 0.5945 - val_loss: 0.7916 - val_y1_output_loss: 0.2123 - val_y2_output_loss: 0.5687 - val_y1_output_root_mean_squared_error: 0.4666 - val_y2_output_root_mean_squared_error: 0.7576
# Epoch 467/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.5893 - y1_output_loss: 0.1495 - y2_output_loss: 0.4395 - y1_output_root_mean_squared_error: 0.3870 - y2_output_root_mean_squared_error: 0.6630 - val_loss: 1.0568 - val_y1_output_loss: 0.2486 - val_y2_output_loss: 0.8020 - val_y1_output_root_mean_squared_error: 0.5027 - val_y2_output_root_mean_squared_error: 0.8967
# Epoch 468/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.5393 - y1_output_loss: 0.1596 - y2_output_loss: 0.3897 - y1_output_root_mean_squared_error: 0.3889 - y2_output_root_mean_squared_error: 0.6229 - val_loss: 0.9336 - val_y1_output_loss: 0.2742 - val_y2_output_loss: 0.6500 - val_y1_output_root_mean_squared_error: 0.5229 - val_y2_output_root_mean_squared_error: 0.8125
# Epoch 469/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4430 - y1_output_loss: 0.1367 - y2_output_loss: 0.3084 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.5552 - val_loss: 1.2187 - val_y1_output_loss: 0.3360 - val_y2_output_loss: 0.8513 - val_y1_output_root_mean_squared_error: 0.5893 - val_y2_output_root_mean_squared_error: 0.9335
# Epoch 470/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4132 - y1_output_loss: 0.1321 - y2_output_loss: 0.2796 - y1_output_root_mean_squared_error: 0.3646 - y2_output_root_mean_squared_error: 0.5294 - val_loss: 0.9167 - val_y1_output_loss: 0.2220 - val_y2_output_loss: 0.6805 - val_y1_output_root_mean_squared_error: 0.4751 - val_y2_output_root_mean_squared_error: 0.8312
# Epoch 471/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.7330 - y1_output_loss: 0.1852 - y2_output_loss: 0.5434 - y1_output_root_mean_squared_error: 0.4310 - y2_output_root_mean_squared_error: 0.7398 - val_loss: 0.7759 - val_y1_output_loss: 0.2053 - val_y2_output_loss: 0.5535 - val_y1_output_root_mean_squared_error: 0.4593 - val_y2_output_root_mean_squared_error: 0.7516
# Epoch 472/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4262 - y1_output_loss: 0.1327 - y2_output_loss: 0.2930 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5424 - val_loss: 0.8245 - val_y1_output_loss: 0.2030 - val_y2_output_loss: 0.6054 - val_y1_output_root_mean_squared_error: 0.4562 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5273 - y1_output_loss: 0.1454 - y2_output_loss: 0.3828 - y1_output_root_mean_squared_error: 0.3816 - y2_output_root_mean_squared_error: 0.6178 - val_loss: 1.6257 - val_y1_output_loss: 0.2033 - val_y2_output_loss: 1.3998 - val_y1_output_root_mean_squared_error: 0.4557 - val_y2_output_root_mean_squared_error: 1.1908
# Epoch 474/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5181 - y1_output_loss: 0.1553 - y2_output_loss: 0.3599 - y1_output_root_mean_squared_error: 0.3947 - y2_output_root_mean_squared_error: 0.6020 - val_loss: 0.8431 - val_y1_output_loss: 0.2384 - val_y2_output_loss: 0.5855 - val_y1_output_root_mean_squared_error: 0.4947 - val_y2_output_root_mean_squared_error: 0.7736
# Epoch 475/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4766 - y1_output_loss: 0.1314 - y2_output_loss: 0.3441 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.5867 - val_loss: 2.8869 - val_y1_output_loss: 0.7110 - val_y2_output_loss: 2.1032 - val_y1_output_root_mean_squared_error: 0.8539 - val_y2_output_root_mean_squared_error: 1.4689
# Epoch 476/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4444 - y1_output_loss: 0.1213 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3486 - y2_output_root_mean_squared_error: 0.5682 - val_loss: 0.7051 - val_y1_output_loss: 0.1706 - val_y2_output_loss: 0.5227 - val_y1_output_root_mean_squared_error: 0.4179 - val_y2_output_root_mean_squared_error: 0.7283
# Epoch 477/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.6248 - y1_output_loss: 0.1677 - y2_output_loss: 0.4600 - y1_output_root_mean_squared_error: 0.4087 - y2_output_root_mean_squared_error: 0.6766 - val_loss: 0.8576 - val_y1_output_loss: 0.2372 - val_y2_output_loss: 0.6089 - val_y1_output_root_mean_squared_error: 0.4911 - val_y2_output_root_mean_squared_error: 0.7852
# Epoch 478/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4567 - y1_output_loss: 0.1333 - y2_output_loss: 0.3261 - y1_output_root_mean_squared_error: 0.3629 - y2_output_root_mean_squared_error: 0.5701 - val_loss: 0.7880 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.5720 - val_y1_output_root_mean_squared_error: 0.4542 - val_y2_output_root_mean_squared_error: 0.7627
# Epoch 479/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3819 - y1_output_loss: 0.1160 - y2_output_loss: 0.2855 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5165 - val_loss: 3.7261 - val_y1_output_loss: 0.6180 - val_y2_output_loss: 3.0195 - val_y1_output_root_mean_squared_error: 0.7968 - val_y2_output_root_mean_squared_error: 1.7582
# Epoch 480/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5133 - y1_output_loss: 0.1308 - y2_output_loss: 0.3810 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.6176 - val_loss: 0.7888 - val_y1_output_loss: 0.2048 - val_y2_output_loss: 0.5732 - val_y1_output_root_mean_squared_error: 0.4550 - val_y2_output_root_mean_squared_error: 0.7627
# Epoch 481/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3769 - y1_output_loss: 0.1147 - y2_output_loss: 0.2634 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5122 - val_loss: 1.1487 - val_y1_output_loss: 0.2063 - val_y2_output_loss: 0.9296 - val_y1_output_root_mean_squared_error: 0.4566 - val_y2_output_root_mean_squared_error: 0.9697
# Epoch 482/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4940 - y1_output_loss: 0.1362 - y2_output_loss: 0.3546 - y1_output_root_mean_squared_error: 0.3706 - y2_output_root_mean_squared_error: 0.5972 - val_loss: 0.8251 - val_y1_output_loss: 0.2199 - val_y2_output_loss: 0.5868 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.7733
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5067 - y1_output_loss: 0.1529 - y2_output_loss: 0.3517 - y1_output_root_mean_squared_error: 0.3911 - y2_output_root_mean_squared_error: 0.5947 - val_loss: 0.7880 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.5558 - val_y1_output_root_mean_squared_error: 0.4758 - val_y2_output_root_mean_squared_error: 0.7494
# Epoch 484/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.6090 - y1_output_loss: 0.1774 - y2_output_loss: 0.4315 - y1_output_root_mean_squared_error: 0.4197 - y2_output_root_mean_squared_error: 0.6579 - val_loss: 1.0920 - val_y1_output_loss: 0.2815 - val_y2_output_loss: 0.8074 - val_y1_output_root_mean_squared_error: 0.5321 - val_y2_output_root_mean_squared_error: 0.8994
# Epoch 485/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4648 - y1_output_loss: 0.1266 - y2_output_loss: 0.3491 - y1_output_root_mean_squared_error: 0.3520 - y2_output_root_mean_squared_error: 0.5839 - val_loss: 2.4008 - val_y1_output_loss: 0.6649 - val_y2_output_loss: 1.6610 - val_y1_output_root_mean_squared_error: 0.8291 - val_y2_output_root_mean_squared_error: 1.3089
# Epoch 486/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4084 - y1_output_loss: 0.1268 - y2_output_loss: 0.2882 - y1_output_root_mean_squared_error: 0.3541 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 1.9134 - val_y1_output_loss: 0.3134 - val_y2_output_loss: 1.5613 - val_y1_output_root_mean_squared_error: 0.5680 - val_y2_output_root_mean_squared_error: 1.2613
# Epoch 487/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4555 - y1_output_loss: 0.1325 - y2_output_loss: 0.3277 - y1_output_root_mean_squared_error: 0.3646 - y2_output_root_mean_squared_error: 0.5679 - val_loss: 1.1319 - val_y1_output_loss: 0.1913 - val_y2_output_loss: 0.9282 - val_y1_output_root_mean_squared_error: 0.4418 - val_y2_output_root_mean_squared_error: 0.9678
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5581 - y1_output_loss: 0.1432 - y2_output_loss: 0.4198 - y1_output_root_mean_squared_error: 0.3788 - y2_output_root_mean_squared_error: 0.6439 - val_loss: 1.5175 - val_y1_output_loss: 0.2151 - val_y2_output_loss: 1.2793 - val_y1_output_root_mean_squared_error: 0.4691 - val_y2_output_root_mean_squared_error: 1.1390
# Epoch 489/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3750 - y1_output_loss: 0.1283 - y2_output_loss: 0.2447 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.4962 - val_loss: 0.7591 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 0.5646 - val_y1_output_root_mean_squared_error: 0.4292 - val_y2_output_root_mean_squared_error: 0.7582
# Epoch 490/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3786 - y1_output_loss: 0.1186 - y2_output_loss: 0.2585 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.5089 - val_loss: 0.7391 - val_y1_output_loss: 0.1736 - val_y2_output_loss: 0.5558 - val_y1_output_root_mean_squared_error: 0.4215 - val_y2_output_root_mean_squared_error: 0.7493
# Epoch 491/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5286 - y1_output_loss: 0.1552 - y2_output_loss: 0.3846 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.6133 - val_loss: 2.7474 - val_y1_output_loss: 0.6938 - val_y2_output_loss: 1.9853 - val_y1_output_root_mean_squared_error: 0.8464 - val_y2_output_root_mean_squared_error: 1.4252
# Epoch 492/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4839 - y1_output_loss: 0.1313 - y2_output_loss: 0.3500 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5930 - val_loss: 0.7080 - val_y1_output_loss: 0.1879 - val_y2_output_loss: 0.5080 - val_y1_output_root_mean_squared_error: 0.4377 - val_y2_output_root_mean_squared_error: 0.7186
# Epoch 493/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3508 - y1_output_loss: 0.1152 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.4847 - val_loss: 0.6755 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.4862 - val_y1_output_root_mean_squared_error: 0.4226 - val_y2_output_root_mean_squared_error: 0.7049
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.5296 - y1_output_loss: 0.3482 - y2_output_loss: 1.1735 - y1_output_root_mean_squared_error: 0.5892 - y2_output_root_mean_squared_error: 1.0874 - val_loss: 2.2738 - val_y1_output_loss: 0.6955 - val_y2_output_loss: 1.5238 - val_y1_output_root_mean_squared_error: 0.8453 - val_y2_output_root_mean_squared_error: 1.2487
# Epoch 495/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4862 - y1_output_loss: 0.1554 - y2_output_loss: 0.3381 - y1_output_root_mean_squared_error: 0.3930 - y2_output_root_mean_squared_error: 0.5759 - val_loss: 1.6748 - val_y1_output_loss: 0.3258 - val_y2_output_loss: 1.3413 - val_y1_output_root_mean_squared_error: 0.5712 - val_y2_output_root_mean_squared_error: 1.1612
# Epoch 496/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.7315 - y1_output_loss: 0.1796 - y2_output_loss: 0.5472 - y1_output_root_mean_squared_error: 0.4247 - y2_output_root_mean_squared_error: 0.7424 - val_loss: 1.1154 - val_y1_output_loss: 0.2769 - val_y2_output_loss: 0.8135 - val_y1_output_root_mean_squared_error: 0.5327 - val_y2_output_root_mean_squared_error: 0.9119
# Epoch 497/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4404 - y1_output_loss: 0.1402 - y2_output_loss: 0.2997 - y1_output_root_mean_squared_error: 0.3753 - y2_output_root_mean_squared_error: 0.5473 - val_loss: 1.2566 - val_y1_output_loss: 0.1921 - val_y2_output_loss: 1.0525 - val_y1_output_root_mean_squared_error: 0.4425 - val_y2_output_root_mean_squared_error: 1.0300
# Epoch 498/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4028 - y1_output_loss: 0.1255 - y2_output_loss: 0.2791 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5260 - val_loss: 0.9250 - val_y1_output_loss: 0.1660 - val_y2_output_loss: 0.7402 - val_y1_output_root_mean_squared_error: 0.4115 - val_y2_output_root_mean_squared_error: 0.8693
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4820 - y1_output_loss: 0.1370 - y2_output_loss: 0.3435 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5869 - val_loss: 1.0119 - val_y1_output_loss: 0.2785 - val_y2_output_loss: 0.7076 - val_y1_output_root_mean_squared_error: 0.5350 - val_y2_output_root_mean_squared_error: 0.8519
# Epoch 500/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4841 - y1_output_loss: 0.1444 - y2_output_loss: 0.3362 - y1_output_root_mean_squared_error: 0.3811 - y2_output_root_mean_squared_error: 0.5821 - val_loss: 0.9698 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.6935 - val_y1_output_root_mean_squared_error: 0.5148 - val_y2_output_root_mean_squared_error: 0.8395

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.9698 - y1_output_loss: 0.2614 - y2_output_loss: 0.7038 - y1_output_root_mean_squared_error: 0.5148 - y2_output_root_mean_squared_error: 0.8395
# Loss = 0.9697558415400518, Y1_loss = 0.2614006996154785, Y1_mse = 0.5148199796676636, Y2_loss = 0.7037822008132935, Y2_mse = 0.8394737243652344

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
