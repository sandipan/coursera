# %% [markdown]
# # Linear Simple Regression
# > Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## Try total_rooms with total_bedrooms

# %% [markdown]
# ### Simple visualization

# %%
sns.relplot(data = df, x = 'total_rooms', y = 'total_bedrooms')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['total_rooms']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['total_bedrooms']).reshape(-1, 1)

# %% [markdown]
# ### Split train and test data

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %%
model.coef_, model.intercept_
# Out:
# (array([[0.18070511]]), array([61.86755768]))

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
rmse = mean_squared_error(y_true=y_test,y_pred=y_pred,squared=False)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 101.35888011777651 MSE: 23752.731604495282 RMSE: 154.1192123146731 R^2 0.8637647401970822

# %% [markdown]
# ### Visualiza your result

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)

# %% [markdown]
# ## Try median income with median house value

# %% [markdown]
# ### simple visualization

# %%
sns.relplot(data = df, x = 'median_income', y = 'median_house_value')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['median_income']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['median_house_value']).reshape(-1,1)

# %% [markdown]
# ### Split train and test data

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
rmse = mean_squared_error(y_true=y_test,y_pred=y_pred,squared=False)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 61776.93574574111 MSE: 6756173988.71918 RMSE: 82195.94873665721 R^2 0.4940654658976973

# %% [markdown]
# ### Visualiza your result

# %%
model.coef_, model.intercept_
# Out:
# (array([[41854.98097901]]), array([44955.95374405]))

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)

# %% [markdown]
# ## Try households with population

# %% [markdown]
# ### simple visualization

# %%
sns.relplot(data = df, x = 'households', y = 'population')

# %% [markdown]
# ### Prepare independent variable

# %%
x = np.array(df['households']).reshape(-1,1)

# %% [markdown]
# ### Prepare dependent variable

# %%
y = np.array(df['population']).reshape(-1,1)

# %% [markdown]
# ### Split train and test data

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
model = reg.fit(x_train, y_train)

# %%
model.coef_, model.intercept_
# Out:
# (array([[2.74182763]]), array([55.92258466]))

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred)
rmse = mean_squared_error(y_true=y_test,y_pred=y_pred,squared=False)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MAE: {} MSE: {} RMSE: {} R^2 {}'.format(mae, mse, rmse, r2))
# Out:
# MAE: 270.2469967472556 MSE: 184962.76253804995 RMSE: 430.07297350339275 R^2 0.8435552238188913

# %% [markdown]
# ### Visualiza your result

# %%
plt.scatter(x_test, y_test)
plt.scatter(x_test, y_pred)
